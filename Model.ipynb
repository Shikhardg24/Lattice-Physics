# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, r2_score

# %%
data_raw = pd.read_csv('raw.csv', header= None)
data = data_raw[0].str.split(expand=True) # splitting the single string into multiple columns
print(data.describe(include= 'all'))
data = data.apply(pd.to_numeric, errors='coerce') #Doing this since LightGBM can't work on object datatype
# Out:
#                  0            1            2            3            4   \
# count         24000        24000        24000        24000        24000
# unique         7209        24000        24000        24000        24000
# top     1.322200000  1.729207126  3.245963193  3.157587544  2.342418377
# freq             15            1            1            1            1
#
#                  5            6            7            8            9   \
# count         24000        24000        24000        24000        24000
# unique        24000        24000        24000        24000        24000
# top     3.795994630  4.230365499  3.396589019  4.533288081  2.168227396
# freq              1            1            1            1            1
#
#                  10           11           12           13           14  \
# count         24000        24000        24000        24000        24000
# unique        24000        24000        24000        24000        24000
# top     2.691689379  2.865300435  4.048600849  4.211782440  2.511663975
# freq              1            1            1            1            1
#
#                  15           16           17           18           19  \
# count         24000        24000        24000        24000        24000
# unique        24000        23999        24000        24000        24000
# top     4.894983937  2.690165130  1.871209126  3.010708760  1.547153130
# freq              1            2            1            1            1
#
#                  20           21           22           23           24  \
# count         24000        24000        24000        24000        24000
# unique        24000        24000        24000        24000        24000
# top     2.709866993  1.805937803  3.424403006  4.219965317  2.877139746
# freq              1            1            1            1            1
#
#                  25           26           27           28           29  \
# count         24000        24000        24000        24000        24000
# unique        24000        24000        24000        24000        24000
# top     3.788282958  1.461245944  2.909638106  2.063528573  1.894538748
# freq              1            1            1            1            1
#
#                  30           31           32           33           34  \
# count         24000        24000        24000        24000        24000
# unique        24000        24000        24000        24000        24000
# top     1.574387133  1.841169087  2.264666145  4.191833450  1.850395004
# freq              1            1            1            1            1
#
#                  35           36           37           38           39  \
# count         24000        24000        24000        24000        24000
# unique        24000        24000        24000        24000        24000
# top     3.124700733  4.338121684  3.322696403  2.660925927  4.793815933
# freq              1            1            1            1            1
#
#                  40
# count         24000
# unique        24000
# top     2.046197173
# freq              1

# %%
test_raw = pd.read_csv('test.csv' , header = None)
test = test_raw[0].str.split(expand=True)
print(test.describe(include= 'all'))
test = test.apply(pd.to_numeric, errors='coerce')
# Out:
#                  0            1            2            3            4   \
# count           360          360          360          360          360
# unique          348          360          360          360          360
# top     1.333220000  2.137468917  4.424625276  1.550003628  1.169750378
# freq              2            1            1            1            1
#
#                  5            6            7            8            9   \
# count           360          360          360          360          360
# unique          360          360          360          360          360
# top     1.218868548  1.053177773  3.718149624  2.401240180  3.152576470
# freq              1            1            1            1            1
#
#                  10           11           12           13           14  \
# count           360          360          360          360          360
# unique          360          360          360          360          360
# top     3.132008550  1.905239823  1.256912775  2.069079782  1.745163158
# freq              1            1            1            1            1
#
#                  15           16           17           18           19  \
# count           360          360          360          360          360
# unique          360          360          360          360          360
# top     1.101496571  2.220788348  1.453281346  4.710924501  1.527682388
# freq              1            1            1            1            1
#
#                  20           21           22           23           24  \
# count           360          360          360          360          360
# unique          360          360          360          360          360
# top     3.282388173  3.335118599  1.774154362  3.578444997  1.718492401
# freq              1            1            1            1            1
#
#                  25           26           27           28           29  \
# count           360          360          360          360          360
# unique          360          360          360          360          360
# top     1.888656496  3.908951277  1.684912441  2.583618256  1.135756726
# freq              1            1            1            1            1
#
#                  30           31           32           33           34  \
# count           360          360          360          360          360
# unique          360          360          360          360          360
# top     0.901853525  4.301141729  1.018820237  3.872537282  1.353769061
# freq              1            1            1            1            1
#
#                  35           36           37           38           39  \
# count           360          360          360          360          360
# unique          360          360          360          360          360
# top     3.005014992  2.883451325  4.401583744  1.913646036  4.055566837
# freq              1            1            1            1            1
#
#                  40
# count           360
# unique          360
# top     2.841196229
# freq              1

# %%
correlation_matrix = data.corr()
print(correlation_matrix.describe())
# Out:
#               0          1          2          3          4          5   \
# count  41.000000  41.000000  41.000000  41.000000  41.000000  41.000000
# mean    0.151044  -0.105615   0.025347   0.025021   0.023396   0.022577
# std     0.201654   0.205551   0.157666   0.157861   0.157791   0.158011
# min    -0.759605  -0.759605  -0.093509  -0.102983  -0.094113  -0.099956
# 25%     0.098331  -0.132817  -0.002136  -0.003302  -0.004330  -0.005586
# 50%     0.170200  -0.120930   0.000275   0.000928  -0.001727  -0.000521
# 75%     0.185946  -0.099956   0.005781   0.004219   0.003343   0.002502
# max     1.000000   1.000000   1.000000   1.000000   1.000000   1.000000
#
#               6          7          8          9          10         11  \
# count  41.000000  41.000000  41.000000  41.000000  41.000000  41.000000
# mean    0.025376   0.022231   0.022230   0.025246   0.025247   0.027032
# std     0.157537   0.157278   0.157858   0.160302   0.159853   0.161072
# min    -0.086067  -0.058925  -0.089814  -0.134865  -0.109787  -0.162441
# 25%    -0.005532  -0.006482  -0.006204  -0.005322  -0.004866  -0.002629
# 50%     0.001465  -0.002224  -0.000757  -0.000022  -0.000026   0.000892
# 75%     0.006503   0.000013   0.003995   0.003872   0.002788   0.006146
# max     1.000000   1.000000   1.000000   1.000000   1.000000   1.000000
#
#               12         13         14         15         16         17  \
# count  41.000000  41.000000  41.000000  41.000000  41.000000  41.000000
# mean    0.024293   0.024712   0.027729   0.024348   0.023579   0.026083
# std     0.160755   0.160322   0.160706   0.159741   0.158042   0.160327
# min    -0.153884  -0.132356  -0.157820  -0.127942  -0.111738  -0.131087
# 25%    -0.003356  -0.006264  -0.001410  -0.006598  -0.004288  -0.004194
# 50%    -0.000579  -0.000016   0.002798  -0.001101   0.000675  -0.000117
# 75%     0.003755   0.005893   0.006832   0.004886   0.003446   0.005373
# max     1.000000   1.000000   1.000000   1.000000   1.000000   1.000000
#
#               18         19         20         21         22         23  \
# count  41.000000  41.000000  41.000000  41.000000  41.000000  41.000000
# mean    0.025028   0.024261   0.024495   0.026129   0.024749   0.026322
# std     0.161389   0.161289   0.159927   0.160273   0.159986   0.160625
# min    -0.171102  -0.172012  -0.118020  -0.142667  -0.135587  -0.139580
# 25%    -0.004598  -0.004987  -0.006653  -0.003740  -0.003048  -0.003989
# 50%     0.001013  -0.000355  -0.003080   0.001289  -0.001141   0.000381
# 75%     0.005086   0.004582   0.003583   0.006075   0.004022   0.007200
# max     1.000000   1.000000   1.000000   1.000000   1.000000   1.000000
#
#               24         25         26         27         28         29  \
# count  41.000000  41.000000  41.000000  41.000000  41.000000  41.000000
# mean    0.023947   0.024094   0.024252   0.022654   0.027777   0.026915
# std     0.160119   0.159996   0.159860   0.158323   0.160237   0.160045
# min    -0.116436  -0.122605  -0.130301  -0.119702  -0.129828  -0.122917
# 25%    -0.006227  -0.003426  -0.005347  -0.005413  -0.002596  -0.002206
# 50%    -0.002813  -0.001141  -0.000847  -0.001530   0.003331   0.000727
# 75%     0.002241   0.002898   0.005473   0.003332   0.006320   0.004424
# max     1.000000   1.000000   1.000000   1.000000   1.000000   1.000000
#
#               30         31         32         33         34         35  \
# count  41.000000  41.000000  41.000000  41.000000  41.000000  41.000000
# mean    0.024142   0.026889   0.026535   0.024054   0.025320   0.025795
# std     0.159991   0.159831   0.160120   0.159686   0.159321   0.157107
# min    -0.132817  -0.132193  -0.129294  -0.120930  -0.112089  -0.067167
# 25%    -0.005802  -0.002218  -0.004674  -0.006807  -0.006068  -0.003392
# 50%    -0.001197   0.000212   0.001993  -0.000914  -0.000096  -0.000171
# 75%     0.002986   0.005464   0.005148   0.003591   0.004310   0.005447
# max     1.000000   1.000000   1.000000   1.000000   1.000000   1.000000
#
#               36         37         38         39         40
# count  41.000000  41.000000  41.000000  41.000000  41.000000
# mean    0.026361   0.026510   0.024032   0.026678   0.024653
# std     0.159322   0.159175   0.156859   0.158843   0.156995
# min    -0.113655  -0.108519  -0.038380  -0.096323  -0.051214
# 25%    -0.003087  -0.003109  -0.005117  -0.002998  -0.004631
# 50%     0.000361  -0.000275  -0.000516   0.000275   0.000717
# 75%     0.004579   0.005113   0.003164   0.004789   0.004796
# max     1.000000   1.000000   1.000000   1.000000   1.000000

# %% [markdown]
# # Looking at the means, I think column 0 and 1 are the targets, since they have the highest means, also column 0 only has about 7200 unique datas

# %%
y_train = data.iloc[:, 0:2]  # Assuming first two columns are targets
X_train = data.iloc[:, 2:]  
y_test = test.iloc[:, 0:2]
X_test = test.iloc[:, 2:]

# %% [markdown]
# # Random Forest Regressor Model

# %%
model = RandomForestRegressor(n_estimators=200, random_state=42)
model.fit(X_train, y_train)
# Out:
# RandomForestRegressor(n_estimators=200, random_state=42)

# %%
y_pred = model.predict(X_test)

mae = mean_absolute_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f"Mean Absolute Error: {mae}")
print(f"R² Score: {r2}")
# Out:
# Mean Absolute Error: 0.040477095354902876
# R² Score: 0.49372987991412254

# %% [markdown]
# # Tried to tune hyperparameters for random forest but somehow got worse results than just the default model, wasted 30 mins on this, ignore this cell. Leaving the output untouched just to show attempt.  Also had to use GPT to learn how to do this..

# %%
import optuna
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import cross_val_score

# Define the objective function
def objective(trial):
    n_estimators = trial.suggest_int('n_estimators', 100, 1000)
    max_depth = trial.suggest_int('max_depth', 5, 50)
    min_samples_split = trial.suggest_int('min_samples_split', 2, 20)
    min_samples_leaf = trial.suggest_int('min_samples_leaf', 1, 10)
    max_features = trial.suggest_categorical('max_features', ['sqrt', 'log2'])

    # Train the Random Forest model
    model = RandomForestRegressor(
        n_estimators=n_estimators,
        max_depth=max_depth,
        min_samples_split=min_samples_split,
        min_samples_leaf=min_samples_leaf,
        max_features=max_features,
        random_state=42,
        n_jobs= -1
    )

    # Cross-validation score
    scores = cross_val_score(model, X_train, y_train, cv=5, scoring='r2')
    return scores.mean()  # Return the mean R² score

# Create a study object and optimize
study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=50)

#
 'max_depth': 30, 'min_samples_split': 8, 'min_samples_leaf': 5, 'max_features': 'log2'}. Best is trial 31 with value: 0.4576560173341602.
# [I 2025-01-27 18:07:07,640] Trial 38 finished with value: 0.43969686878639946 and parameters: {'n_estimators': 998, 'max_depth': 25, 'min_samples_split': 13, 'min_samples_leaf': 2, 'max_features': 'sqrt'}. Best is trial 31 with value: 0.4576560173341602.
# [I 2025-01-27 18:07:40,709] Trial 39 finished with value: 0.44937420421357566 and parameters: {'n_estimators': 657, 'max_depth': 40, 'min_samples_split': 5, 'min_samples_leaf': 1, 'max_features': 'log2'}. Best is trial 31 with value: 0.4576560173341602.
# [I 2025-01-27 18:07:48,090] Trial 40 finished with value: 0.44517990651259803 and parameters: {'n_estimators': 149, 'max_depth': 18, 'min_samples_split': 7, 'min_samples_leaf': 3, 'max_features': 'sqrt'}. Best is trial 31 with value: 0.4576560173341602.
# [I 2025-01-27 18:08:39,408] Trial 41 finished with value: 0.4575986168969954 and parameters: {'n_estimators': 939, 'max_depth': 36, 'min_samples_split': 3, 'min_samples_leaf': 1, 'max_features': 'sqrt'}. Best is trial 31 with value: 0.4576560173341602.
# [I 2025-01-27 18:09:33,358] Trial 42 finished with value: 0.4554687642995298 and parameters: {'n_estimators': 935, 'max_depth': 40, 'min_samples_split': 2, 'min_samples_leaf': 2, 'max_features': 'sqrt'}. Best is trial 31 with value: 0.4576560173341602.
# [I 2025-01-27 18:10:23,198] Trial 43 finished with value: 0.4574711855315979 and parameters: {'n_estimators': 786, 'max_depth': 32, 'min_samples_split': 3, 'min_samples_leaf': 1, 'max_features': 'sqrt'}. Best is trial 31 with value: 0.4576560173341602.
# [I 2025-01-27 18:11:16,889] Trial 44 finished with value: 0.4534331394889968 and parameters: {'n_estimators': 942, 'max_depth': 36, 'min_samples_split': 5, 'min_samples_leaf': 2, 'max_features': 'sqrt'}. Best is trial 31 with value: 0.4576560173341602.
# [I 2025-01-27 18:11:43,874] Trial 45 finished with value: 0.4560619338598988 and parameters: {'n_estimators': 411, 'max_depth': 33, 'min_samples_split': 3, 'min_samples_leaf': 1, 'max_features': 'sqrt'}. Best is trial 31 with value: 0.4576560173341602.
# [I 2025-01-27 18:12:28,931] Trial 46 finished with value: 0.4461307879357017 and parameters: {'n_estimators': 875, 'max_depth': 42, 'min_samples_split': 2, 'min_samples_leaf': 4, 'max_features': 'sqrt'}. Best is trial 31 with value: 0.4576560173341602.
# [I 2025-01-27 18:12:59,358] Trial 47 finished with value: 0.4062857499290047 and parameters: {'n_estimators': 737, 'max_depth': 12, 'min_samples_split': 12, 'min_samples_leaf': 1, 'max_features': 'log2'}. Best is trial 31 with value: 0.4576560173341602.
# [I 2025-01-27 18:13:43,813] Trial 48 finished with value: 0.42766416605893787 and parameters: {'n_estimators': 953, 'max_depth': 29, 'min_samples_split': 4, 'min_samples_leaf': 8, 'max_features': 'sqrt'}. Best is trial 31 with value: 0.4576560173341602.
# [I 2025-01-27 18:14:41,917] Trial 49 finished with value: 0.45171435804202975 and parameters: {'n_estimators': 1000, 'max_depth': 23, 'min_samples_split': 6, 'min_samples_leaf': 2, 'max_features': 'sqrt'}. Best is trial 31 with value: 0.4576560173341602.
# Best Parameters: {'n_estimators': 920, 'max_depth': 27, 'min_samples_split': 3, 'min_samples_leaf': 1, 'max_features': 'sqrt'}
# Best R² Score: 0.4576560173341602

# %% [markdown]
# # LightGBM Model

# %%
from lightgbm import LGBMRegressor
from sklearn.multioutput import MultiOutputRegressor

model = LGBMRegressor(random_state=42)
model = MultiOutputRegressor(model)  #LightGBM can only work with one target by default, have to wrap it with MultiOutputRegressor

model.fit(X_train, y_train)

predictions = model.predict(X_test)
# Out:
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001514 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 9945
# [LightGBM] [Info] Number of data points in the train set: 24000, number of used features: 39
# [LightGBM] [Info] Start training from score 1.325139
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001218 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 9945
# [LightGBM] [Info] Number of data points in the train set: 24000, number of used features: 39
# [LightGBM] [Info] Start training from score 1.883559

# %%
r2_target1 = r2_score(y_test.iloc[:, 0], predictions[:, 0])  # Infinite Multiplication Factor
r2_target2 = r2_score(y_test.iloc[:, 1], predictions[:, 1])  # PPPF

print(f"R² Score for Infinite Multiplication Factor: {r2_target1}")
print(f"R² Score for PPPF: {r2_target2}")
# Out:
# R² Score for Infinite Multiplication Factor: 0.828330478930373
# R² Score for PPPF: 0.6970344349224671

# %% [markdown]
# # LGBM gives the best results.
